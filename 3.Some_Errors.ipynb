# %% [markdown]
# # Some Errors:

# %% [markdown]
# ### Installing ONNX:
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Tried Things:
#
# 1. Update pip and setuptools
#
# it didn't had anything have to do with pip?
# Install the necessary build tools for your operating system.
#
# 2. On Windows, this often involves installing Visual Studio Build Tools.
#
# 3. This didn't work, so I tried a stable version of Python.
#
# This didn't work either, so I thought I'd create a virtual environment to avoid outside factors.
# and this did work eventualy but not with any extra problems:

# %% [markdown]
# -----------

# %% [markdown]
# # The VENV:

# %% [markdown]
# #### Problems with powershell:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# I have managed to get the venv working for version 3.12.1, now to get it working for a stable 3.9 version.
#
# I have installed 3.9 and added it to the path, but it is not being recognized. Also, using different forms of the command, it eventually worked after I had found the following two things:
#
# * Installation Directory Permissions: Insufficient permissions to write to the installation directory may prevent Python from being installed properly.
#
# And there was an antivirus on my PC that I had temporarily for some tests that was causing problems, I threw it off and then it worked.
#
# * Antivirus Software: Overly aggressive antivirus software may block Python installation processes or flag them as potentially harmful.

# %% [markdown]
# wrong version:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ----------
# # Setup ONNX (in the venv):

# %% [markdown]
# ONNX Does not want to be found. I solved this just by reinstalling ONNX and with the exact same commandos as before and after that it worked:

# %% [markdown]
# ![image.png](attachment:image.png)
